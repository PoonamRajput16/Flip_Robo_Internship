# %% [markdown]
# # Webscrapping - 3

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\91977\anaconda3\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\users\91977\anaconda3\lib\site-packages (from selenium) (1.26.4)

# %%
import selenium
import pandas as pd
from selenium import webdriver

from time import sleep
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %% [markdown]
# _____________________

# %% [markdown]
# #### 1. Write a python program which searches all the product under a particular product vertical from www.amazon.in. The product verticals to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
user_input1 = input('Enter the product title to search: ')
# Out:
# Enter the product title to search: iphone

# %%
    driver = webdriver.Chrome(r"C:\Users\91977\Downloads\chromedriver_win32\chromedriver.exe")
    driver.get('https://www.amazon.in/')
    time.sleep(1)
    
    srch_bar = driver.find_element_by_id('twotabsearchtextbox')    
    srch_bar.clear()                                               
    srch_bar.send_keys(user_input1)                                   
    srch_button = driver.find_element_by_id('nav-search-submit-button')
    srch_button.click()

# %% [markdown]
# #### 2. Scrape all the products available under that product vertical

# %%
    Product = {}
    Product['Brand'] = []
    Product['Product_Title'] = []
    Product['Price'] = []
    Product['Ratings'] = []
    Product['No.of_Ratings'] = []
    Product['Return/Exchange'] = []
    Product['Expected_Delivery'] = []    
    Product['Availability'] = []
    Product['Other_Details'] = []
    Product['Product_URL'] = []

# %%
    next_page = []
    for i in driver.find_elements_by_xpath('//li[@class="a-normal"]//a'):
        try:
            next_page.append(i.get_attribute('href'))
        except NoSuchElementException:
            next_page.append('-') 
    
    urls = []
    for i in driver.find_elements_by_xpath('//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]//a'):
        try:
            urls.append(i.get_attribute('href'))
        except NoSuchElementException:
            urls.append('-')

# %%
next_page
# Out:
# ['https://www.amazon.in/s?k=iphone&page=2&qid=1627235371&ref=sr_pg_2',
#  'https://www.amazon.in/s?k=iphone&page=3&qid=1627235371&ref=sr_pg_3']

# %%
len(urls)
# Out:
# 18

# %%
    for i in urls:
        try:
            Product['Product_URL'].append(i)
        except:
            Product['Product_URL'].append('-')

# %%
    for j in urls:
        driver.get(j)
        
        try:
            brand = driver.find_element_by_id('bylineInfo')
            Product['Brand'].append(brand.text.replace('Visit the','').replace('Brand:','').replace('Store',''))
        except NoSuchElementException:
            Product['Brand'].append('-')
        
        try:
            title = driver.find_element_by_id('productTitle')
            Product['Product_Title'].append(title.text)
        except NoSuchElementException:
            Product['Product_Title'].append('-')
        
        try:
            price = driver.find_element_by_id('priceblock_ourprice')
            Product['Price'].append(price.text)
        except NoSuchElementException:
            Product['Price'].append('-')
        
        try:
            ratings = driver.find_element_by_xpath('//span[@class="a-size-base a-nowrap"]')
            Product['Ratings'].append(ratings.text.replace('out of 5',''))
        except NoSuchElementException:
            Product['Ratings'].append('-')
        
        try:
            n_ratings = driver.find_element_by_id('acrCustomerReviewText')
            Product['No.of_Ratings'].append(n_ratings.text.replace('rating','').replace('ratings','').replace('s',''))
        except NoSuchElementException:
            Product['No.of_Ratings'].append('-')

        try:
            returns = driver.find_element_by_xpath('//div[@data-name="RETURNS_POLICY"]/span/div[2]/a')
            Product['Return/Exchange'].append(returns.text)
        except NoSuchElementException:
            Product['Return/Exchange'].append('-')
    
        try:
            delivery = delivery = driver.find_element_by_xpath('//div[@id="ddmDeliveryMessage"]/b') 
            Product['Expected_Delivery'].append(delivery.text.replace('FREE delivery:','').replace('Details',''))
        except NoSuchElementException:
            Product['Expected_Delivery'].append('-')
        
        try:
            availability = driver.find_element_by_xpath('//div[@id="availability"]/span')
            Product['Availability'].append(availability.text)
        except NoSuchElementException:
            Product['Availability'].append('-')
            
        try:
            details = driver.find_element_by_xpath('//ul[@class="a-unordered-list a-vertical a-spacing-mini"]')
            Product['Other_Details'].append(details.text)
        except NoSuchElementException:
            Product['Other_Details'].append('-')
        
        time.sleep(5)

# %%
print(len(Product['Brand']),len(Product['Product_Title']),len(Product['Price']),len(Product['Product_URL']),
      len(Product['No.of_Ratings']),len(Product['Ratings']),len(Product['Return/Exchange']),
      len(Product['Expected_Delivery']),len(Product['Other_Details']),len(Product['Availability']))
# Out:
# 18 18 18 18 18 18 18 18 18 18

# %%
for i in range(0,2):
    driver.get(next_page[i])
    try:        
        time.sleep(2)
        urls = []
        for i in driver.find_elements_by_xpath('//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]//a'):
            try:
                urls.append(i.get_attribute('href'))
            except NoSuchElementException:
                urls.append('-')
                
        for i in urls:
            try:
                Product['Product_URL'].append(i)
            except:
                Product['Product_URL'].append('-')
                
        for j in urls:
            driver.get(j)
        
        
            try:
                brand = driver.find_element_by_id('bylineInfo')
                Product['Brand'].append(brand.text.replace('Visit the','').replace('Brand:','').replace('Store',''))
            except NoSuchElementException:
                Product['Brand'].append('-')
        
            try:
                title = driver.find_element_by_id('productTitle')
                Product['Product_Title'].append(title.text)
            except NoSuchElementException:
                Product['Product_Title'].append('-')
        
            try:
                price = driver.find_element_by_id('priceblock_ourprice')
                Product['Price'].append(price.text)
            except NoSuchElementException:
                Product['Price'].append('-')
        
            try:
                ratings = driver.find_element_by_xpath('//span[@class="a-size-base a-nowrap"]')
                Product['Ratings'].append(ratings.text.replace('out of 5',''))
            except NoSuchElementException:
                Product['Ratings'].append('-')
        
            try:
                n_ratings = driver.find_element_by_id('acrCustomerReviewText')
                Product['No.of_Ratings'].append(n_ratings.text.replace('rating','').replace('ratings','').replace('s',''))
            except NoSuchElementException:
                Product['No.of_Ratings'].append('-')

            try:
                returns = driver.find_element_by_xpath('//div[@data-name="RETURNS_POLICY"]/span/div[2]/a')
                Product['Return/Exchange'].append(returns.text)
            except NoSuchElementException:
                Product['Return/Exchange'].append('-')
    
            try:
                delivery = delivery = driver.find_element_by_xpath('//div[@id="ddmDeliveryMessage"]/b') 
                Product['Expected_Delivery'].append(delivery.text.replace('FREE delivery:','').replace('Details',''))
            except NoSuchElementException:
                Product['Expected_Delivery'].append('-')
        
            try:
                availability = driver.find_element_by_xpath('//div[@id="availability"]/span')
                Product['Availability'].append(availability.text)
            except NoSuchElementException:
                Product['Availability'].append('-')
            
            try:
                details = driver.find_element_by_xpath('//ul[@class="a-unordered-list a-vertical a-spacing-mini"]')
                Product['Other_Details'].append(details.text)
            except NoSuchElementException:
                Product['Other_Details'].append('-')
        
            time.sleep(5)

    except NoSuchElementException:
        pass

# %%
print(len(Product['Brand']),len(Product['Product_Title']),len(Product['Price']),len(Product['Product_URL']),
      len(Product['No.of_Ratings']),len(Product['Ratings']),len(Product['Return/Exchange']),
      len(Product['Expected_Delivery']),len(Product['Other_Details']),len(Product['Availability']))
# Out:
# 54 54 54 54 54 54 54 54 54 54

# %%
Amazon_Products = pd.DataFrame(Product)

# %%
Amazon_Products
# Out:
#        Brand                                      Product_Title         Price  \
# 0     Apple                 New Apple iPhone 11 (64GB) - Purple    ₹50,999.00
# 1     Apple                  New Apple iPhone 12 (64GB) - Black    ₹71,900.00
# 2     Apple                  New Apple iPhone 11 (64GB) - Black    ₹49,999.00
# 3     Apple                 New Apple iPhone 11 (128GB) - White    ₹56,999.00
# 4     Apple                  New Apple iPhone 11 (64GB) - White    ₹50,999.00
# 5     Apple                 New Apple iPhone XR (128GB) - White    ₹42,999.00
# 6     Apple                 New Apple iPhone 11 (128GB) - Black    ₹57,999.00
# 7     Apple                  New Apple iPhone XR (128GB) - Blue    ₹42,999.00
# 8     Apple                 New Apple iPhone XR (128GB) - Black    ₹42,999.00
# 9     Apple                New Apple iPhone 11 (128GB) - Purple    ₹58,999.00
# 10    Apple                   New Apple iPhone XR (64GB) - Blue    ₹47,900.00
# 11    Apple                 New Apple iPhone 11 (128GB) - Green    ₹56,999.00
# 12    Apple                 New Apple iPhone XR (64GB) - Yellow    ₹37,999.00
# 13    Apple                 New Apple iPhone 11 (64GB) - Purple    ₹50,999.00
# 14    Apple                      Apple iPhone XR (64GB) - Black    ₹37,999.00
# 15    Apple         New Apple iPhone XR (128GB) - (Product) RED    ₹42,999.00
# 16        4G  5S Gold Compatible with iPhone with (16GB Inte...    ₹14,999.00
# 17    Apple                  New Apple iPhone XR (64GB) - White    ₹37,999.00
# 18        MI  Mi 11X Pro 5G (Lunar White, 8GB RAM, 128GB Sto...    ₹39,999.00
# 19    Tecno   Tecno Spark 7T(Jewel Blue, 4GB RAM, 64GB Stora...     ₹8,999.00
# 20    Apple                  New Apple iPhone 11 (64GB) - Green    ₹52,900.00
# 21    Apple          New Apple iPhone 11 (64GB) - (Product) RED    ₹52,900.00
# 22    Apple                New Apple iPhone 11 (128GB) - Yellow    ₹57,999.00
# 23    Apple         New Apple iPhone 11 (128GB) - (Product) RED    ₹56,999.00
# 24    Apple            New Apple iPhone 12 Mini (64GB) - Purple    ₹65,900.00
# 25    Apple                 New Apple iPhone 11 (256GB) - White    ₹69,900.00
# 26    Apple   New Apple iPhone 12 Pro Max (128GB) - Pacific ...  ₹1,24,700.00
# 27    Apple          New Apple iPhone XR (64GB) - (Product) RED    ₹37,999.00
# 28    Apple                New Apple iPhone XR (128GB) - Yellow    ₹52,900.00
# 29        4G  6G Space Grey Compatible with iPhone with (16G...    ₹18,999.00
# 30    Tecno   Tecno Spark 7T(Magnet Black, 4GB RAM,64GB Stor...     ₹8,999.00
# 31    Apple                New Apple iPhone 12 (128GB) - Purple    ₹72,999.00
# 32    Apple                  New Apple iPhone 12 (64GB) - White    ₹70,900.00
# 33    Apple                 New Apple iPhone 11 (64GB) - Yellow    ₹53,250.00
# 34    Apple           New Apple iPhone 12 Mini (128GB) - Purple    ₹71,150.00
# 35    Apple                  New Apple iPhone 12 (128GB) - Blue    ₹72,999.00
# 36        MI  Mi 11X Pro 5G (Cosmic Black, 8GB RAM, 128GB St...    ₹39,999.00
# 37    Tecno   Tecno Spark 7T(Magnet Black, 4GB RAM,64GB Stor...     ₹8,999.00
# 38    Apple                  New Apple iPhone 12 (64GB) - Black    ₹71,900.00
# 39    Apple                New Apple iPhone 11 (256GB) - Purple    ₹69,900.00
# 40    Apple      New Apple iPhone 12 Pro (128GB) - Pacific Blue  ₹1,15,100.00
# 41   Nillkin  Nillkin Tempered Glass for Apple iPhone X (5.8...     ₹1,999.00
# 42    Apple                 New Apple iPhone 12 (64GB) - Purple    ₹73,900.00
# 43    Apple                 New Apple iPhone 12 (128GB) - White    ₹72,999.00
# 44    Apple                 New Apple iPhone 12 (128GB) - Black    ₹72,999.00
# 45    Apple                   New Apple iPhone 12 (64GB) - Blue    ₹72,900.00
# 46    Apple        Apple iPhone 11 Pro Max (512GB) - Space Grey             -
# 47    Apple                  New Apple iPhone 12 (64GB) - Green    ₹71,900.00
# 48    Apple          New Apple iPhone 12 Pro Max (256GB) - Gold  ₹1,39,899.00
# 49    Apple                 New Apple iPhone 11 (256GB) - Black    ₹69,900.00
# 50    Apple                New Apple iPhone 11 (256GB) - Yellow    ₹69,900.00
# 51    Apple         New Apple iPhone 12 (128GB) - (Product) RED    ₹72,999.00
# 52    Apple   New Apple iPhone 12 Pro Max (256GB) - Pacific ...  ₹1,32,200.00
# 53    Apple        Apple iPhone 11 Pro (512GB) - Midnight Green    ₹94,900.00
#
#    Ratings No.of_Ratings     Return/Exchange  Expected_Delivery  \
# 0     4.6        34,390                    -    July 30 - Aug 1
# 1     4.6         4,521                    -      Monday, Aug 2
# 2     4.6        34,390                    -    July 31 - Aug 1
# 3     4.6        34,390                    -      Monday, Aug 2
# 4     4.6        34,390                    -    Friday, July 30
# 5       5             1                    -  Thursday, July 29
# 6     4.6        34,390                    -      Monday, Aug 2
# 7       5             1                    -  Thursday, July 29
# 8       5             1                    -  Thursday, July 29
# 9     4.6        34,390                    -       July 29 - 31
# 10      5             1                    -  Thursday, July 29
# 11    4.6        34,390                    -    July 28 - Aug 4
# 12      5             1                    -  Thursday, July 29
# 13    4.6        34,390                    -    July 30 - Aug 1
# 14      5             1                    -  Thursday, July 29
# 15      5             1                    -  Thursday, July 29
# 16       -             -  7 Days Replacement  Saturday, July 31
# 17      5             1                    -  Thursday, July 29
# 18    3.9           579   7 Days Replacement  Thursday, July 29
# 19      4         1,234   7 Days Replacement  Thursday, July 29
# 20    4.6        34,390                    -      Monday, Aug 2
# 21    4.6        34,390                    -  Thursday, July 29
# 22    4.6        34,390                    -       July 29 - 31
# 23    4.6        34,390                    -    July 30 - Aug 1
# 24    4.5         4,945                    -          Sep 4 - 6
# 25    4.6        34,390                    -    Friday, July 30
# 26    4.6           883                    -  Thursday, July 29
# 27      5             1                    -  Thursday, July 29
# 28      5             1                    -  Thursday, July 29
# 29       -             -  7 Days Replacement  Saturday, July 31
# 30      4         1,234   7 Days Replacement  Thursday, July 29
# 31    4.6         4,521                    -  Saturday, July 31
# 32    4.6         4,521                    -        Aug 28 - 30
# 33    4.6        34,390                    -  Thursday, July 29
# 34    4.5         4,945                    -          Aug 2 - 7
# 35    4.6         4,521                    -  Saturday, July 31
# 36    3.9           579   7 Days Replacement  Thursday, July 29
# 37      4         1,234   7 Days Replacement  Thursday, July 29
# 38    4.6         4,521                    -      Monday, Aug 2
# 39    4.6        34,390                    -    Friday, July 30
# 40    4.5           400                    -  Thursday, July 29
# 41       -             -  7 Days Replacement    Friday, July 30
# 42    4.6         4,521                    -  Thursday, July 29
# 43    4.6         4,521                    -  Thursday, July 29
# 44    4.6         4,521                    -      Monday, Aug 2
# 45    4.6         4,521                    -  Thursday, July 29
# 46    4.5         1,175                    -                  -
# 47    4.6         4,521                    -  Thursday, July 29
# 48    4.6           883                    -  Thursday, July 29
# 49    4.6        34,390                    -          Aug 2 - 6
# 50    4.6        34,390                    -      Sunday, Aug 1
# 51    4.6         4,521                    -  Thursday, July 29
# 52    4.6           883                    -  Thursday, July 29
# 53    4.6         1,138                    -  Saturday, July 31
#
#                       Availability  \
# 0       In stock on July 28, 2021.
# 1                        In stock.
# 2       In stock on July 29, 2021.
# 3                        In stock.
# 4                        In stock.
# 5                        In stock.
# 6                        In stock.
# 7                        In stock.
# 8                        In stock.
# 9                        In stock.
# 10                       In stock.
# 11                       In stock.
# 12                       In stock.
# 13      In stock on July 28, 2021.
# 14                       In stock.
# 15                       In stock.
# 16                       In stock.
# 17                       In stock.
# 18                       In stock.
# 19                       In stock.
# 20                       In stock.
# 21                       In stock.
# 22  Available to ship in 1-2 days.
# 23      In stock on July 28, 2021.
# 24  In stock on September 2, 2021.
# 25                       In stock.
# 26                       In stock.
# 27                       In stock.
# 28                       In stock.
# 29           Only 1 left in stock.
# 30                       In stock.
# 31                       In stock.
# 32    In stock on August 26, 2021.
# 33                       In stock.
# 34      In stock on July 31, 2021.
# 35                       In stock.
# 36                       In stock.
# 37                       In stock.
# 38                       In stock.
# 39                       In stock.
# 40                       In stock.
# 41           Only 1 left in stock.
# 42                       In stock.
# 43                       In stock.
# 44                       In stock.
# 45                       In stock.
# 46          Currently unavailable.
# 47                       In stock.
# 48                       In stock.
# 49      In stock on July 31, 2021.
# 50           Only 1 left in stock.
# 51                       In stock.
# 52                       In stock.
# 53           Only 1 left in stock.
#
#                                         Other_Details  \
# 0   6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 1   6.1-inch (15.5 cm diagonal) Super Retina XDR d...
# 2   6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 3   6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 4   6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 5   6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 6   6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 7   6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 8   6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 9   6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 10  6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 11  6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 12  6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 13  6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 14  6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 15  6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 16  8MP primary camera with true tone flash, auto ...
# 17  6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 18  Qualcomm Snapdragon 888 5G with Kryo 680 Octa-...
# 19  48MP AI Dual Rear Camera | 8MP Selfie Camera w...
# 20  6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 21  6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 22  6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 23  6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 24  5.4-inch (13.7 cm diagonal) Super Retina XDR d...
# 25  6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 26  6.7-inch (17 cm diagonal) Super Retina XDR dis...
# 27  6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 28  6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 29  8MP primary camera with auto focus and 1.2MP f...
# 30  48MP AI Dual Rear Camera 8MP Selfie Camera wit...
# 31  6.1-inch (15.5 cm diagonal) Super Retina XDR d...
# 32  6.1-inch (15.5 cm diagonal) Super Retina XDR d...
# 33  6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 34  5.4-inch (13.7 cm diagonal) Super Retina XDR d...
# 35  6.1-inch (15.5 cm diagonal) Super Retina XDR d...
# 36  Qualcomm Snapdragon 888 5G with Kryo 680 Octa-...
# 37  48MP AI Dual Rear Camera 8MP Selfie Camera wit...
# 38  6.1-inch (15.5 cm diagonal) Super Retina XDR d...
# 39  6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 40  6.1-inch (15.5 cm diagonal) Super Retina XDR d...
# 41  Daily Shoppers is Authorized Nillkin seller, N...
# 42  6.1-inch (15.5 cm diagonal) Super Retina XDR d...
# 43  6.1-inch (15.5 cm diagonal) Super Retina XDR d...
# 44  6.1-inch (15.5 cm diagonal) Super Retina XDR d...
# 45  6.1-inch (15.5 cm diagonal) Super Retina XDR d...
# 46  6.5-inch (16.5 cm diagonal) Super Retina XDR O...
# 47  6.1-inch (15.5 cm diagonal) Super Retina XDR d...
# 48  6.7-inch (17 cm diagonal) Super Retina XDR dis...
# 49  6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 50  6.1-inch (15.5 cm diagonal) Liquid Retina HD L...
# 51  6.1-inch (15.5 cm diagonal) Super Retina XDR d...
# 52  6.7-inch (17 cm diagonal) Super Retina XDR dis...
# 53  5.8-inch (14.7 cm diagonal) Super Retina XDR O...
#
#                                           Product_URL
# 0   https://www.amazon.in/gp/slredirect/picassoRed...
# 1   https://www.amazon.in/gp/slredirect/picassoRed...
# 2   https://www.amazon.in/New-Apple-iPhone-11-64GB...
# 3   https://www.amazon.in/New-Apple-iPhone-11-128G...
# 4   https://www.amazon.in/New-Apple-iPhone-11-64GB...
# 5   https://www.amazon.in/New-Apple-iPhone-XR-128G...
# 6   https://www.amazon.in/New-Apple-iPhone-11-128G...
# 7   https://www.amazon.in/New-Apple-iPhone-XR-128G...
# 8   https://www.amazon.in/New-Apple-iPhone-XR-128G...
# 9   https://www.amazon.in/New-Apple-iPhone-11-128G...
# 10  https://www.amazon.in/New-Apple-iPhone-XR-64GB...
# 11  https://www.amazon.in/New-Apple-iPhone-11-128G...
# 12  https://www.amazon.in/New-Apple-iPhone-XR-64GB...
# 13  https://www.amazon.in/New-Apple-iPhone-11-64GB...
# 14  https://www.amazon.in/New-Apple-iPhone-XR-64GB...
# 15  https://www.amazon.in/New-Apple-iPhone-XR-128G...
# 16  https://www.amazon.in/5S-Compatible-iPhone-Int...
# 17  https://www.amazon.in/New-Apple-iPhone-XR-64GB...
# 18  https://www.amazon.in/gp/slredirect/picassoRed...
# 19  https://www.amazon.in/gp/slredirect/picassoRed...
# 20  https://www.amazon.in/New-Apple-iPhone-11-64GB...
# 21  https://www.amazon.in/New-Apple-iPhone-11-64GB...
# 22  https://www.amazon.in/New-Apple-iPhone-11-128G...
# 23  https://www.amazon.in/New-Apple-iPhone-11-128G...
# 24  https://www.amazon.in/New-Apple-iPhone-Mini-64...
# 25  https://www.amazon.in/New-Apple-iPhone-11-256G...
# 26  https://www.amazon.in/New-Apple-iPhone-Pro-128...
# 27  https://www.amazon.in/New-Apple-iPhone-XR-64GB...
# 28  https://www.amazon.in/New-Apple-iPhone-XR-128G...
# 29  https://www.amazon.in/6G-Compatible-iPhone-Int...
# 30  https://www.amazon.in/Tecno-Magnet-Storage-Bat...
# 31  https://www.amazon.in/New-Apple-iPhone-12-128G...
# 32  https://www.amazon.in/New-Apple-iPhone-12-64GB...
# 33  https://www.amazon.in/New-Apple-iPhone-11-64GB...
# 34  https://www.amazon.in/New-Apple-iPhone-Mini-12...
# 35  https://www.amazon.in/New-Apple-iPhone-12-128G...
# 36  https://www.amazon.in/gp/slredirect/picassoRed...
# 37  https://www.amazon.in/gp/slredirect/picassoRed...
# 38  https://www.amazon.in/New-Apple-iPhone-12-64GB...
# 39  https://www.amazon.in/New-Apple-iPhone-11-256G...
# 40  https://www.amazon.in/New-Apple-iPhone-Pro-128...
# 41  https://www.amazon.in/Nillkin-Tempered-Shaterp...
# 42  https://www.amazon.in/New-Apple-iPhone-12-64GB...
# 43  https://www.amazon.in/New-Apple-iPhone-12-128G...
# 44  https://www.amazon.in/New-Apple-iPhone-12-128G...
# 45  https://www.amazon.in/New-Apple-iPhone-12-64GB...
# 46  https://www.amazon.in/Apple-iPhone-Pro-Max-512...
# 47  https://www.amazon.in/New-Apple-iPhone-12-64GB...
# 48  https://www.amazon.in/New-Apple-iPhone-Pro-256...
# 49  https://www.amazon.in/New-Apple-iPhone-11-256G...
# 50  https://www.amazon.in/New-Apple-iPhone-11-256G...
# 51  https://www.amazon.in/New-Apple-iPhone-12-128G...
# 52  https://www.amazon.in/New-Apple-iPhone-Pro-256...
# 53  https://www.amazon.in/Apple-iPhone-11-Pro-512G...

# %%
Amazon_Products.to_csv('Amazon_Products.csv')

# %% [markdown]
# __________________

# %% [markdown]
# ### 3. Write a python program to access the search bar and search button on images.google.com and scrape 100 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’.

# %%
def scrap_images(url3):
    Images = {}
    Images['Keyword1'] =[]
    Images['Keyword2'] = []
    Images['Keyword3'] = []
      
    driver = webdriver.Chrome(r"C:\Users\91977\Downloads\chromedriver_win32\chromedriver.exe")
    
    #keyword1    
    driver.get(url3)
    time.sleep(1)
    print('\n')
    input1 = input('Enter the keyword to search images: ')
    print('Extracting',input1,' images!!!!')
    
    srch_bar3 = driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')    
    srch_bar3.clear()                                               
    srch_bar3.send_keys(input1)                                   
    srch_button3 = driver.find_element_by_xpath('//button[@class="Tg7LZd"]')
    srch_button3.click()
    
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)#sleep_between_interactions
    
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)
    
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)
    
    images = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')
    
    u1 = []
    for i in images:
        try:
            u1.append(i)
        except NoSuchElementException:
            pass
    for i in range(0,len(u1)):
        if i<100:
            print('image',i,' is dowloaded')
            
    for i in driver.find_elements_by_xpath('//a[@class="VFACy kGQAp sMi44c lNHeqe WGvvNb"]'):
        Images['Keyword1'].append(i.get_attribute('href'))
    Images['Keyword1'] = Images['Keyword1'][:100]
    
    #keyword2
    driver.get(url3)
    time.sleep(1)
    print('\n')
    input2 = input('Enter the keyword to search images: ')
    print('Extracting',input2,' images!!!!')
    
    srch_bar3 = driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')    
    srch_bar3.clear()                                               
    srch_bar3.send_keys(input2)                                   
    srch_button3 = driver.find_element_by_xpath('//button[@class="Tg7LZd"]')
    srch_button3.click()
    
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)#sleep_between_interactions
    
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)
    
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)
    
    images = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')
    
    u2 = []
    for i in images:
        try:
            u2.append(i)
        except NoSuchElementException:
            pass
    for i in range(0,len(u2)):
        if i<100:
            print('image',i,' is dowloaded')            
    for i in driver.find_elements_by_xpath('//a[@class="VFACy kGQAp sMi44c lNHeqe WGvvNb"]'):
        Images['Keyword2'].append(i.get_attribute('href'))   
    Images['Keyword2'] = Images['Keyword2'][:100]
        
    
    #keyword3
    driver.get(url3)
    time.sleep(1)
    print('\n')
    input3 = input('Enter the keyword to search images: ')
    print('Extracting',input3,' images!!!!')
    
    srch_bar3 = driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')    
    srch_bar3.clear()                                               
    srch_bar3.send_keys(input3)                                   
    srch_button3 = driver.find_element_by_xpath('//button[@class="Tg7LZd"]')
    srch_button3.click()
    
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)#sleep_between_interactions
    
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)
    
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)
    
    images = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')
    u3 = []
    for i in images:
        try:
            u3.append(i)
        except NoSuchElementException:
            pass
    
    for i in range(0,len(u3)):
        if i<100:
            print('image',i,' is dowloaded')
            
    for i in driver.find_elements_by_xpath('//a[@class="VFACy kGQAp sMi44c lNHeqe WGvvNb"]'):
        Images['Keyword3'].append(i.get_attribute('href'))    
    Images['Keyword3'] = Images['Keyword3'][:100]
    
    
    print(len(Images['Keyword1']),len(Images['Keyword2']),len(Images['Keyword3']))
    Images = pd.DataFrame(Images)
    print(Images)

# %%
url3 = 'https://images.google.com/'

# %%
scrap_images(url3)
# Out:
# Enter the keyword to search images: fruits
# Extracting fruits  images!!!!
# image 0  is dowloaded
# image 1  is dowloaded
# image 2  is dowloaded
# image 3  is dowloaded
# image 4  is dowloaded
# image 5  is dowloaded
# image 6  is dowloaded
# image 7  is dowloaded
# image 8  is dowloaded
# image 9  is dowloaded
# image 10  is dowloaded
# image 11  is dowloaded
# image 12  is dowloaded
# image 13  is dowloaded
# image 14  is dowloaded
# image 15  is dowloaded
# image 16  is dowloaded
# image 17  is dowloaded
# image 18  is dowloaded
# image 19  is dowloaded
# image 20  is dowloaded
# image 21  is dowloaded
# image 22  is dowloaded
# image 23  is dowloaded
# image 24  is dowloaded
# image 25  is dowloaded
# image 26  is dowloaded
# image 27  is dowloaded
# image 28  is dowloaded
# image 29  is dowloaded
# image 30  is dowloaded
# image 31  is dowloaded
# image 32  is dowloaded
# image 33  is dowloaded
# image 34  is dowloaded
# image 35  is dowloaded
# image 36  is dowloaded
# image 37  is dowloaded
# image 38  is dowloaded
# image 39  is dowloaded
# image 40  is dowloaded
# image 41  is dowloaded
# image 42  is dowloaded
# image 43  is dowloaded
# image 44  is dowloaded
# image 45  is dowloaded
# image 46  is dowloaded
# image 47  is dowloaded
# image 48  is dowloaded
# image 49  is dowloaded
# image 50  is dowloaded
# image 51  is dowloaded
# image 52  is dowloaded
# image 53  is dowloaded
# image 54  is dowloaded
# image 55  is dowloaded
# image 56  is dowloaded
# image 57  is dowloaded
# image 58  is dowloaded
# image 59  is dowloaded
# image 60  is dowloaded
# image 61  is dowloaded
# image 62  is dowloaded
# image 63  is dowloaded
# image 64  is dowloaded
# image 65  is dowloaded
# image 66  is dowloaded
# image 67  is dowloaded
# image 68  is dowloaded
# image 69  is dowloaded
# image 70  is dowloaded
# image 71  is dowloaded
# image 72  is dowloaded
# image 73  is dowloaded
# image 74  is dowloaded
# image 75  is dowloaded
# image 76  is dowloaded
# image 77  is dowloaded
# image 78  is dowloaded
# image 79  is dowloaded
# image 80  is dowloaded
# image 81  is dowloaded
# image 82  is dowloaded
# image 83  is dowloaded
# image 84  is dowloaded
# image 85  is dowloaded
# image 86  is dowloaded
# image 87  is dowloaded
# image 88  is dowloaded
# image 89  is dowloaded
# image 90  is dowloaded
# image 91  is dowloaded
# image 92  is dowloaded
# image 93  is dowloaded
# image 94  is dowloaded
# image 95  is dowloaded
# image 96  is dowloaded
# image 97  is dowloaded
# image 98  is dowloaded
# image 99  is dowloaded
#
#
# Enter the keyword to search images: cars
# Extracting cars  images!!!!
# image 0  is dowloaded
# image 1  is dowloaded
# image 2  is dowloaded
# image 3  is dowloaded
# image 4  is dowloaded
# image 5  is dowloaded
# image 6  is dowloaded
# image 7  is dowloaded
# image 8  is dowloaded
# image 9  is dowloaded
# image 10  is dowloaded
# image 11  is dowloaded
# image 12  is dowloaded
# image 13  is dowloaded
# image 14  is dowloaded
# image 15  is dowloaded
# image 16  is dowloaded
# image 17  is dowloaded
# image 18  is dowloaded
# image 19  is dowloaded
# image 20  is dowloaded
# image 21  is dowloaded
# image 22  is dowloaded
# image 23  is dowloaded
# image 24  is dowloaded
# image 25  is dowloaded
# image 26  is dowloaded
# image 27  is dowloaded
# image 28  is dowloaded
# image 29  is dowloaded
# image 30  is dowloaded
# image 31  is dowloaded
# image 32  is dowloaded
# image 33  is dowloaded
# image 34  is dowloaded
# image 35  is dowloaded
# image 36  is dowloaded
# image 37  is dowloaded
# image 38  is dowloaded
# image 39  is dowloaded
# image 40  is dowloaded
# image 41  is dowloaded
# image 42  is dowloaded
# image 43  is dowloaded
# image 44  is dowloaded
# image 45  is dowloaded
# image 46  is dowloaded
# image 47  is dowloaded
# image 48  is dowloaded
# image 49  is dowloaded
# image 50  is dowloaded
# image 51  is dowloaded
# image 52  is dowloaded
# image 53  is dowloaded
# image 54  is dowloaded
# image 55  is dowloaded
# image 56  is dowloaded
# image 57  is dowloaded
# image 58  is dowloaded
# image 59  is dowloaded
# image 60  is dowloaded
# image 61  is dowloaded
# image 62  is dowloaded
# image 63  is dowloaded
# image 64  is dowloaded
# image 65  is dowloaded
# image 66  is dowloaded
# image 67  is dowloaded
# image 68  is dowloaded
# image 69  is dowloaded
# image 70  is dowloaded
# image 71  is dowloaded
# image 72  is dowloaded
# image 73  is dowloaded
# image 74  is dowloaded
# image 75  is dowloaded
# image 76  is dowloaded
# image 77  is dowloaded
# image 78  is dowloaded
# image 79  is dowloaded
# image 80  is dowloaded
# image 81  is dowloaded
# image 82  is dowloaded
# image 83  is dowloaded
# image 84  is dowloaded
# image 85  is dowloaded
# image 86  is dowloaded
# image 87  is dowloaded
# image 88  is dowloaded
# image 89  is dowloaded
# image 90  is dowloaded
# image 91  is dowloaded
# image 92  is dowloaded
# image 93  is dowloaded
# image 94  is dowloaded
# image 95  is dowloaded
# image 96  is dowloaded
# image 97  is dowloaded
# image 98  is dowloaded
# image 99  is dowloaded
#
#
# Enter the keyword to search images: Machine Learning
# Extracting Machine Learning  images!!!!
# image 0  is dowloaded
# image 1  is dowloaded
# image 2  is dowloaded
# image 3  is dowloaded
# image 4  is dowloaded
# image 5  is dowloaded
# image 6  is dowloaded
# image 7  is dowloaded
# image 8  is dowloaded
# image 9  is dowloaded
# image 10  is dowloaded
# image 11  is dowloaded
# image 12  is dowloaded
# image 13  is dowloaded
# image 14  is dowloaded
# image 15  is dowloaded
# image 16  is dowloaded
# image 17  is dowloaded
# image 18  is dowloaded
# image 19  is dowloaded
# image 20  is dowloaded
# image 21  is dowloaded
# image 22  is dowloaded
# image 23  is dowloaded
# image 24  is dowloaded
# image 25  is dowloaded
# image 26  is dowloaded
# image 27  is dowloaded
# image 28  is dowloaded
# image 29  is dowloaded
# image 30  is dowloaded
# image 31  is dowloaded
# image 32  is dowloaded
# image 33  is dowloaded
# image 34  is dowloaded
# image 35  is dowloaded
# image 36  is dowloaded
# image 37  is dowloaded
# image 38  is dowloaded
# image 39  is dowloaded
# image 40  is dowloaded
# image 41  is dowloaded
# image 42  is dowloaded
# image 43  is dowloaded
# image 44  is dowloaded
# image 45  is dowloaded
# image 46  is dowloaded
# image 47  is dowloaded
# image 48  is dowloaded
# image 49  is dowloaded
# image 50  is dowloaded
# image 51  is dowloaded
# image 52  is dowloaded
# image 53  is dowloaded
# image 54  is dowloaded
# image 55  is dowloaded
# image 56  is dowloaded
# image 57  is dowloaded
# image 58  is dowloaded
# image 59  is dowloaded
# image 60  is dowloaded
# image 61  is dowloaded
# image 62  is dowloaded
# image 63  is dowloaded
# image 64  is dowloaded
# image 65  is dowloaded
# image 66  is dowloaded
# image 67  is dowloaded
# image 68  is dowloaded
# image 69  is dowloaded
# image 70  is dowloaded
# image 71  is dowloaded
# image 72  is dowloaded
# image 73  is dowloaded
# image 74  is dowloaded
# image 75  is dowloaded
# image 76  is dowloaded
# image 77  is dowloaded
# image 78  is dowloaded
# image 79  is dowloaded
# image 80  is dowloaded
# image 81  is dowloaded
# image 82  is dowloaded
# image 83  is dowloaded
# image 84  is dowloaded
# image 85  is dowloaded
# image 86  is dowloaded
# image 87  is dowloaded
# image 88  is dowloaded
# image 89  is dowloaded
# image 90  is dowloaded
# image 91  is dowloaded
# image 92  is dowloaded
# image 93  is dowloaded
# image 94  is dowloaded
# image 95  is dowloaded
# image 96  is dowloaded
# image 97  is dowloaded
# image 98  is dowloaded
# image 99  is dowloaded
# 100 100 100
#                                              Keyword1  \
# 0   https://www.goodhousekeeping.com/health/diet-n...
# 1   https://www.pinterest.com/pin/649081365039047796/
# 2   https://www.amazon.in/Fruits-All-One-Dreamland...
# 3         https://www.youtube.com/watch?v=PY2OxP_jMZ0
# 4   https://www.healthyeating.org/nutrition-topics...
# ..                                                ...
# 95  https://www.mysouthernhealth.com/9-refreshing-...
# 96  https://timesofindia.indiatimes.com/life-style...
# 97  https://www.eatforhealth.gov.au/food-essential...
# 98  https://www.gas-x.com/amp/summer-fruits-cause-...
# 99  https://www.india.com/food/8-nutrient-rich-fru...
#
#                                              Keyword2  \
# 0   https://www.popularmechanics.com/cars/a3482425...
# 1   https://www.forbes.com/sites/jimgorzelany/2019...
# 2   https://luxe.digital/lifestyle/cars/fastest-cars/
# 3   https://www.extremetech.com/extreme/303740-car...
# 4   https://www.ft.com/content/8089bb56-30fe-11ea-...
# ..                                                ...
# 95  https://www.hotstar.com/in/movies/cars-3/12600...
# 96  https://www.autoexpress.co.uk/106907/best-spor...
# 97                       https://cars.tatamotors.com/
# 98             https://www.wired.com/tag/car-hacking/
# 99  https://speedvegas.com/fastest-cars-in-the-world/
#
#                                              Keyword3
# 0   https://data-flair.training/blogs/machine-lear...
# 1   https://www.forbes.com/sites/tomtaulli/2019/03...
# 2   https://www.analyticsvidhya.com/blog/2021/03/a...
# 3   https://www.blumeglobal.com/learning/machine-l...
# 4   https://towardsdatascience.com/machine-learnin...
# ..                                                ...
# 95  https://www.sas.com/en_in/insights/analytics/m...
# 96  https://www.ovhcloud.com/en/public-cloud/ai-ma...
# 97    https://www.ti.com/tool/SITARA-MACHINE-LEARNING
# 98  https://www.toptal.com/machine-learning/machin...
# 99  https://analyticsindiamag.com/a-beginners-guid...
#
# [100 rows x 3 columns]

# %% [markdown]
# _______________________________________________________________

# %% [markdown]
# ### 4. Write a python program to search for a smartphone

# %%
import selenium
import pandas as pd
from selenium import webdriver

from time import sleep
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
driver = webdriver.Chrome(r"C:\Users\91977\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('https://www.flipkart.com/')
driver.find_element_by_xpath("//div[@class='_2QfC02']/button").click()
search = driver.find_element_by_xpath("//form[@class='_2M8cLY header-form-search']/div/div/input")
user_inp = input('Enter the smartphone you want to search : ')
search.send_keys(user_inp)
driver.find_element_by_xpath("//button[@class='L0Z3Pu']").click()
# Out:
# Enter the smartphone you want to search : redmi 9

# %%
url = []
for i in driver.find_elements_by_xpath("//div[@class='_2kHMtA']/a"):
    url.append(i.get_attribute('href'))

# %%
product_name = []
brand_name = []
Price = []
#brand_name
for page in url :
    driver.get(page)
    try :  
        name = driver.find_element_by_xpath("//h1[@class='yhB1nd']/span")
        if name.text is None :
            brand_name.append("-")
        else :
            brand_name.append(name.text)
    
    except NoSuchElementException :
        brand_name.append("-")

# %%
#Price
for page in url :
    driver.get(page)
    try : 
        price = driver.find_element_by_xpath("//div[@class='_25b18c']/div")
        if price.text is None :
            Price.append("-")
        else :
            Price.append(price.text)
    except NoSuchElementException :
        Price.append("-")

# %%
ratings = []
for page in url :
    driver.get(page)
    driver.find_element_by_xpath("//div[@class='_3_L3jD']/div/span/div").click()
    try : 
        rate = driver.find_element_by_xpath("//div[@class='col-4-12']/div/div/div/div")
        if rate.text is None :
            ratings.append("-")
        else :
            ratings.append(rate.text)
    except NoSuchElementException :
        ratings.append("-")
        
    time.sleep(5)

# %% [markdown]
# color = []
# for page in url:
#     driver.get(page)
#     driver.find_element_by_xpath("//tr[@class='_1s_Smc row']/td[2]/ul/li")

# %%
colors = []
for page in url :
    driver.get(page)
    try : 
        col = driver.find_element_by_xpath("//div[@class='_1AtVbE col-12-12']/div/div/div/div/table/tbody/tr[4]/td[2]/ul/li")
        if col.text is None :
            colors.append("-")
        else :
            colors.append(col.text)
    except NoSuchElementException :
        colors.append("-")
        
    time.sleep(5)

# %%
RAM = []
for page in url :
    driver.get(page)
    driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
    try : 
        ram = driver.find_element_by_xpath("//div[@class='_1AtVbE col-12-12']/div/div/div/div[4]/table/tbody/tr[2]/td[2]/ul/li")
        if ram.text is None :
            RAM.append("-")
        else :
            RAM.append(ram.text)
    except NoSuchElementException :
        RAM.append("-")
        
    time.sleep(5)

# %%
storage = []
for page in url :
    driver.get(page)
    driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
    try : 
        stor = driver.find_element_by_xpath("//div[@class='_1AtVbE col-12-12']/div/div/div/div[4]/table/tbody/tr[1]/td/ul/li")
        if stor.text is None :
            storage.append("-")
        else :
            storage.append(stor.text)
    except NoSuchElementException :
        storage.append("-")
        
    time.sleep(5)

# %%
display = []
for page in url :
    driver.get(page)
    driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
    try : 
        disp = driver.find_element_by_xpath("//div[@class='_1AtVbE col-12-12']/div/div/div[1]/div[2]/table/tbody/tr[1]/td/ul/li")
        if disp.text is None :
            display.append("-")
        else :
            display.append(disp.text)
    except NoSuchElementException :
        display.append("-")
        
    time.sleep(5)

# %%
display_res = []
for page in url :
    driver.get(page)
    driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
    try : 
        dr = driver.find_element_by_xpath("//div[@class='_1AtVbE col-12-12']/div/div/div[1]/div[2]/table/tbody/tr[2]/td/ul/li")
        if dr.text is None :
            display_res.append("-")
        else :
            display_res.append(dr.text)
    except NoSuchElementException :
        display_res.append("-")
        
    time.sleep(5)

# %%
processor = []
for page in url :
    driver.get(page)
    driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
    try : 
        p = driver.find_element_by_xpath("//div[@class='_1AtVbE col-12-12']/div/div/div[1]/div[3]/table/tbody/tr[2]/td/ul/li")
        if p.text is None :
            processor.append("-")
        else :
            processor.append(p.text)
    except NoSuchElementException :
        processor.append("-")
        
    time.sleep(5)

# %%
primary_camera = []
for page in url :
    driver.get(page)
    driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
    try : 
        pc = driver.find_element_by_xpath("//div[@class='_1AtVbE col-12-12']/div/div/div[1]/div[5]/table/tbody/tr[2]/td/ul/li")
        if pm.text is None :
            primary_camera.append("-")
        else :
            primary_camera.append(pc.text)
    except NoSuchElementException :
        primary_camera.append("-")
        
    time.sleep(5)

# %%
secondary_cam = []
for page in url :
    driver.get(page)
    driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
    try : 
        sc = driver.find_element_by_xpath("//div[@class='_1AtVbE col-12-12']/div/div/div[1]/div[5]/table/tbody/tr[5]/td/ul/li")
        if sc.text is None :
            secondary_camera.append("-")
        else :
            secondary_camera.append(sc.text)
    except NoSuchElementException :
        secondary_camera.append("-")
        
    time.sleep(5)

# %%
battery = []
for page in url :
    driver.get(page)
    driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
    try : 
        b = driver.find_element_by_xpath("//div[@class='_1AtVbE col-12-12']/div/div/div[1]/div[10]/table/tbody/tr[1]/td/ul/li")
        if b.text is None :
            battery.append("-")
        else :
            battery.append(b.text)
    except NoSuchElementException :
        battery.append("-")
        
    time.sleep(5)

# %%
Flipkart = pd.DataFrame({})

# %%
Flipkart['Brand_name'] = brand_name
Flipkart['Price'] = Price
Flipkart['Ratings'] = ratings
Flipkart['Color'] = colors
Flipkart['RAM'] = RAM
Flipkart['ROM'] = storage
Flipkart['Display_size']=display
Flipkart['Display_resolution']=display_res
Flipkart['Processor']=processor
Flipkart['Primary_camera']=primary_camera
Flipkart['Secondary_camera']=secondary_camera
Flipkart['Battery']=battery
Flipkart['Product_url']=url

# %%
def search_smartphone(url4):
    Smartphone = {}
    Smartphone['Brand_Name'] =[]
    Smartphone['Smartphone_name'] = []
    Smartphone['Colour'] = []
    Smartphone['RAM'] = []
    Smartphone['Storage(ROM)'] = []
    Smartphone['Primary_Camera'] = []
    Smartphone['Secondary_Camera'] = []
    Smartphone['Display_Size'] = []
    Smartphone['Display_Resolution'] = []
    Smartphone['Processor'] = []
    Smartphone['Processor_Cores'] = []
    Smartphone['Battery_Capacity'] = []
    Smartphone['Price'] = []
    Smartphone['Product_URL'] = []

      
    driver = webdriver.Chrome(r"C:\Users\91977\Downloads\chromedriver_win32\chromedriver.exe")
    
    driver.get(url4)
    time.sleep(2)
    
    close = driver.find_element_by_xpath('//button[@class="_2KpZ6l _2doB4z"]')
    close.click()

    input1 = input('Enter the Smart Product Name: ')
    
    srch_bar4 = driver.find_element_by_xpath('//input[@class="_3704LK"]')    
    srch_bar4.clear()                                               
    srch_bar4.send_keys(input1)                                   
    srch_button4 = driver.find_element_by_xpath('//button[@class="L0Z3Pu"]')
    srch_button4.click()

    links = []
    for i in driver.find_elements_by_xpath('//a[@class="_1fQZEK"]'):
        try:
            links.append(i.get_attribute('href'))
        except NoSuchElementException:
            links.append('-')

# %%
    driver = webdriver.Chrome(r"C:\Users\91977\Downloads\chromedriver_win32\chromedriver.exe")
    url4 = 'https://www.flipkart.com/'
    driver.get(url4)

# %%
    close = driver.find_element_by_xpath('//button[@class="_2KpZ6l _2doB4z"]')
    close.click()

# %%
    input1 = input('Enter the Smartphone Product Name: ')
# Out:
# Enter the Smartphone Product Name: igel

# %%
    srch_bar4 = driver.find_element_by_xpath('//input[@class="_3704LK"]')    
    srch_bar4.clear()                                               
    srch_bar4.send_keys(input1)                                   
    srch_button4 = driver.find_element_by_xpath('//button[@class="L0Z3Pu"]')
    srch_button4.click()

# %%
    links = []
    for i in driver.find_elements_by_xpath('//a[@class="_1fQZEK"]'):
        try:
            links.append(i.get_attribute('href'))
        except NoSuchElementException:
            links.append('-')

# %%
len(links)
# Out:
# 0

# %%
for i in range(0,1):
    driver.get(links[i])
    try:
        read_more = driver.find_element_by_xpath('//button[@class="_2KpZ6l _1FH0tX"]')     
        read_more.click()
    except NoSuchElementException:
        print("Exception Occured. Moving to next page")    
    #Colour
    try:
        b=driver.find_element_by_xpath('//span[@id="_14cfVK"]')#/td[2]/ul/li
        Smartphone['Colour'].append(b.text)  
    except NoSuchElementException:
        Smartphone['Colour'].append('-')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-57-65cc92b46c22> in <module>
#       1 for i in range(0,1):
# ----> 2     driver.get(links[i])
#       3     try:
#       4         read_more = driver.find_element_by_xpath('//button[@class="_2KpZ6l _1FH0tX"]')
#       5         read_more.click()
#
# IndexError: list index out of range

# %%
Smartphone['Colour']

# %%
    for i in range(0,len(links)):
        driver.get(i)
        
        try:
            read_more = driver.find_element_by_xpath('//button[@class="_2KpZ6l _1FH0tX"]')     
            read_more.click()
        except NoSuchElementException:
            print("Exception Occured. Moving to next page")
            
        try:
            b = driver.find_element_by_xpath('//div[@class="_2WkVRV"])
            Smartphone['Brand_Name'].append(b)  
        except NoSuchElementException:
            Smartphone['Brand_Name'].append('-')                              
        try:
            name = driver.find_element_by_xpath('//h1[@class="yhB1nd"]//span)
            Smartphone['Smartphone_name'].append(name)  
        except NoSuchElementException:
            Smartphone['Smartphone_name'].append('-')   
                                                
        #Colour
        try:
            b = driver.find_element_by_xpath('//div[@class="_2WkVRV"])
            Smartphone['Colour'].append(b)  
        except NoSuchElementException:
            Smartphone['Colour'].append('-')           
                                            
        try:
            b = driver.find_element_by_xpath('//div[@class="_2WkVRV"])
            Smartphone['Brand_Name'].append(b)  
        except NoSuchElementException:
            Smartphone['Brand_Name'].append('-')   
        try:
            b = driver.find_element_by_xpath('//div[@class="_2WkVRV"])
            Smartphone['Brand_Name'].append(b)  
        except NoSuchElementException:
            Smartphone['Brand_Name'].append('-')   
        try:
            b = driver.find_element_by_xpath('//div[@class="_2WkVRV"])
            Smartphone['Brand_Name'].append(b)  
        except NoSuchElementException:
            Smartphone['Brand_Name'].append('-')
        try:
            b = driver.find_element_by_xpath('//div[@class="_2WkVRV"])
            Smartphone['Brand_Name'].append(b)  
        except NoSuchElementException:
            Smartphone['Brand_Name'].append('-')   
                                             
        try:
            b = driver.find_element_by_xpath('//div[@class="_2uWkVRV"])
            Smartphone['Brand_Name'].append(b)  
        except NoSuchElementException:
            Smartphone['Brand_Name'].append('-')                                                
                                             
        try:
            b = driver.find_element_by_xpath('//div[@class="_2WkVRV"])
            Smartphone['Brand_Name'].append(b)  
        except NoSuchElementException:
            Smartphone['Brand_Name'].append('-')                                                
                                             
        try:
            b = driver.find_element_by_xpath('//div[@class="_2WkVRV"])
            Smartphone['Brand_Name'].append(b)  
        except NoSuchElementException:
            Smartphone['Brand_Name'].append('-')                                                
                                             
        try:
            b = driver.find_element_by_xpath('//div[@class="_2WkVRV"])
            Smartphone['Brand_Name'].append(b)  
        except NoSuchElementException:
            Smartphone['Brand_Name'].append('-')                                                
                                             
        try:
            b = driver.find_element_by_xpath('//div[@class="_2WkVRV"])
            Smartphone['Brand_Name'].append(b)  
        except NoSuchElementException:
            Smartphone['Brand_Name'].append('-')                                                
                                             
        try:
            b = driver.find_element_by_xpath('//div[@class="_2WkVRV"])
            Smartphone['Brand_Name'].append(b)  
        except NoSuchElementException:
            Smartphone['Brand_Name'].append('-')                                                
                                             
        try:
            b = driver.find_element_by_xpath('//div[@class="_2WkVRV"])
            Smartphone['Brand_Name'].append(b)  
        except NoSuchElementException:
            Smartphone['Brand_Name'].append('-')                                                
                                             
        try:
            b = driver.find_element_by_xpath('//div[@class="_2WkVRV"])
            Smartphone['Brand_Name'].append(b)  
        except NoSuchElementException:
            Smartphone['Brand_Name'].append('-')

# %%
    Smartphone = {}
    Smartphone['Colour'] = []
    Smartphone['RAM'] = []
    Smartphone['Storage(ROM)'] = []
    Smartphone['Primary_Camera'] = []
    Smartphone['Secondary_Camera'] = []
    Smartphone['Display_Size'] = []
    Smartphone['Display_Resolution'] = []
    Smartphone['Processor'] = []
    Smartphone['Processor_Cores'] = []
    Smartphone['Battery_Capacity'] = []
    Smartphone['Price'] = []
    Smartphone['Product_URL'] = []

# %%
url = []
for i in driver.find_elements_by_xpath("//div[@class='_2kHMtA']/a"):
    url.append(i.get_attribute('href'))

# %%
product_name = []
brand_name = []
Price = []
#brand_name
for page in url :
    driver.get(page)
    try :  
        name = driver.find_element_by_xpath("//h1[@class='yhB1nd']/span")
        if name.text is None :
            brand_name.append("-")
        else :
            brand_name.append(name.text)
    
    except NoSuchElementException :
        brand_name.append("-")

# %%
#Price
for page in url :
    driver.get(page)
    try : 
        price = driver.find_element_by_xpath("//div[@class='_25b18c']/div")
        if price.text is None :
            Price.append("-")
        else :
            Price.append(price.text)
    except NoSuchElementException :
        Price.append("-")

# %%
ratings = []
for page in url :
    driver.get(page)
    driver.find_element_by_xpath("//div[@class='_3_L3jD']/div/span/div").click()
    try : 
        rate = driver.find_element_by_xpath("//div[@class='col-4-12']/div/div/div/div")
        if rate.text is None :
            ratings.append("-")
        else :
            ratings.append(rate.text)
    except NoSuchElementException :
        ratings.append("-")
        
    time.sleep(5)

# %%
color = []
for page in url:
    driver.get(page)
    driver.find_element_by_xpath("//tr[@class='_1s_Smc row']/td[2]/ul/li")

# %%
colors = []
for page in url :
    driver.get(page)
    try : 
        col = driver.find_element_by_xpath("//div[@class='_1AtVbE col-12-12']/div/div/div/div/table/tbody/tr[4]/td[2]/ul/li")
        if col.text is None :
            colors.append("-")
        else :
            colors.append(col.text)
    except NoSuchElementException :
        colors.append("-")
        
    time.sleep(5)

# %%
driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']")

# %%
RAM = []
for page in url :
    driver.get(page)
    driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
    try : 
        ram = driver.find_element_by_xpath("//div[@class='_1AtVbE col-12-12']/div/div/div/div[4]/table/tbody/tr[2]/td[2]/ul/li")
        if ram.text is None :
            RAM.append("-")
        else :
            RAM.append(ram.text)
    except NoSuchElementException :
        RAM.append("-")
        
    time.sleep(5)

# %%
storage = []
for page in url :
    driver.get(page)
    driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
    try : 
        stor = driver.find_element_by_xpath("//div[@class='_1AtVbE col-12-12']/div/div/div/div[4]/table/tbody/tr[1]/td/ul/li")
        if stor.text is None :
            storage.append("-")
        else :
            storage.append(stor.text)
    except NoSuchElementException :
        storage.append("-")
        
    time.sleep(5)

# %%
display = []
for page in url :
    driver.get(page)
    driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
    try : 
        disp = driver.find_element_by_xpath("//div[@class='_1AtVbE col-12-12']/div/div/div[1]/div[2]/table/tbody/tr[1]/td/ul/li")
        if disp.text is None :
            display.append("-")
        else :
            display.append(disp.text)
    except NoSuchElementException :
        display.append("-")
        
    time.sleep(5)

# %%
display_res = []
for page in url :
    driver.get(page)
    driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
    try : 
        dr = driver.find_element_by_xpath("//div[@class='_1AtVbE col-12-12']/div/div/div[1]/div[2]/table/tbody/tr[2]/td/ul/li")
        if dr.text is None :
            display_res.append("-")
        else :
            display_res.append(dr.text)
    except NoSuchElementException :
        display_res.append("-")
        
    time.sleep(5)

# %%
processor = []
for page in url :
    driver.get(page)
    driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
    try : 
        p = driver.find_element_by_xpath("//div[@class='_1AtVbE col-12-12']/div/div/div[1]/div[3]/table/tbody/tr[2]/td/ul/li")
        if p.text is None :
            processor.append("-")
        else :
            processor.append(p.text)
    except NoSuchElementException :
        processor.append("-")
        
    time.sleep(5)

# %%
primary_camera = []
for page in url :
    driver.get(page)
    driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
    try : 
        pc = driver.find_element_by_xpath("//div[@class='_1AtVbE col-12-12']/div/div/div[1]/div[5]/table/tbody/tr[2]/td/ul/li")
        if pm.text is None :
            primary_camera.append("-")
        else :
            primary_camera.append(pc.text)
    except NoSuchElementException :
        primary_camera.append("-")
        
    time.sleep(5)

# %%
secondary_cam = []
for page in url :
    driver.get(page)
    driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
    try : 
        sc = driver.find_element_by_xpath("//div[@class='_1AtVbE col-12-12']/div/div/div[1]/div[5]/table/tbody/tr[5]/td/ul/li")
        if sc.text is None :
            secondary_camera.append("-")
        else :
            secondary_camera.append(sc.text)
    except NoSuchElementException :
        secondary_camera.append("-")
        
    time.sleep(5)

# %%
battery = []
for page in url :
    driver.get(page)
    driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
    try : 
        b = driver.find_element_by_xpath("//div[@class='_1AtVbE col-12-12']/div/div/div[1]/div[10]/table/tbody/tr[1]/td/ul/li")
        if b.text is None :
            battery.append("-")
        else :
            battery.append(b.text)
    except NoSuchElementException :
        battery.append("-")
        
    time.sleep(5)

# %%
pd.DataFrame({})

# %%
df['Brand_name'] = brand_name
df['Price'] = Price
df['Ratings'] = ratings
df['Color'] = colors
df['RAM'] = RAM
df['ROM'] = storage
df['Display_size']=display
df['Display_resolution']=display_res
df['Processor']=processor
df['Primary_camera']=primary_camera
df['Secondary_camera']=secondary_camera
df['Battery']=battery
df['Product_url']=url

# %%
    Smartphone = {}
    
    
    brand_name
    Smartphone['Brand_name'] = brand_name
    Smartphone['Colour'] = colors
    Smartphone['RAM'] = RAM
    Smartphone['Storage(ROM)'] = storage
    Smartphone['Primary_Camera'] = primary_camera
    Smartphone['Secondary_Camera'] = secondary_camera
    Smartphone['Display_Size'] = display
    Smartphone['Display_Resolution'] = display_res
    Smartphone['Processor'] = processor
    Smartphone['Battery_Capacity'] = battery
    Smartphone['Price'] = Price
    Smartphone['Product_URL'] = url

# %%
primary_camera

# %%
    for i in driver.find_elements_by_xpath('//div[@class="_2WkVRV"]:
        Smartphone['Brand_Name'].append

# %%
print('Brand_Name', “Smartphone name”, “Colour”, “RAM”,
“Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Display
Resolution”, “Processor”, “Processor Cores”, “Battery Capacity”, “Price”, “Product URL”)
# Out:
#   File "<ipython-input-36-5a935bfef108>", line 1
#     print('Brand_Name', “Smartphone name”, “Colour”, “RAM”,
#                                   ^
# SyntaxError: invalid character in identifier

# %%
driver = webdriver.Chrome(r"C:\Users\91977\Downloads\chromedriver_win32\chromedriver.exe")

url4 = 'https://www.flipkart.com/'
driver.get(url4)
time.sleep(6)

# %%
close = driver.find_element_by_xpath('//button[@class="_2KpZ6l _2doB4z"]')
close.click()

# %%
search4 = driver.find_element_by_xpath("//input[@class='_3704LK']")
search4.clear()
search4.send_keys("iphone 12 pro")

# %%
#Pressing the search button for the results
search_btn4 = driver.find_element_by_xpath('//button[@class="L0Z3Pu"]')
search_btn4.click()

# %%
Title=[]
RAM=[]
Camera=[]
Display_Size=[]
Processor=[]
Battery_Capacity=[]
Price=[]
Product_URL=[]

# %%
#list of all the specifications in the mobile
    Smartphone = {}
    Smartphone['Colour'] = []
    Smartphone['RAM'] = []
    Smartphone['Storage(ROM)'] = []
    Smartphone['Primary_Camera'] = []
    Smartphone['Secondary_Camera'] = []
    Smartphone['Display_Size'] = []
    Smartphone['Display_Resolution'] = []
    Smartphone['Processor'] = []
    Smartphone['Processor_Cores'] = []
    Smartphone['Battery_Capacity'] = []
    Smartphone['Price'] = []
    Smartphone['Product_URL'] = []
    
    
    d on 1st page.
Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”,
“Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Display
Resolution”, “Processor”, “Processor Cores”, “Battery Capacity”, “Price”, “Product URL”.

# %%
# Scraping all the product names
title=driver.find_elements_by_xpath('//div[@class="_4rR01T"]')
for i in title:
    if i.text is None :
        Title.append("--") 
    else:
        Title.append(i.text)
        
# Scraping all the product RAM       
Ram=driver.find_elements_by_xpath("//div[@class='fMghEO']/ul/li[1]")
for i in Ram:
    if i.text is None :
        RAM.append("--") 
    else:
        RAM.append(i.text)
        
# Scraping all the product Cameras(i.e., Primary and Secondary)
cam=driver.find_elements_by_xpath("//div[@class='fMghEO']/ul/li[3]")
for i in cam:
    if i.text is None :
        Camera.append("--") 
    else:
        Camera.append(i.text)

# Scraping all the products display
display=driver.find_elements_by_xpath("//div[@class='fMghEO']/ul/li[2]")
for i in display:
    if i.text is None :
        Display_Size.append("--") 
    else:
        Display_Size.append(i.text)

# Scraping all the products processor
processor=driver.find_elements_by_xpath("//div[@class='fMghEO']/ul/li[5]")
for i in processor:
    if i.text is None :
        Processor.append("--") 
    else:
        Processor.append(i.text)
        
# Scraping all the products Battery
Battery=driver.find_elements_by_xpath("//div[@class='fMghEO']/ul/li[4]")
for i in Battery:
    if i.text is None :
        Battery_Capacity.append("--") 
    else:
        Battery_Capacity.append(i.text)

# Scraping all the products price
price = driver.find_elements_by_xpath("//div[@class='_30jeq3 _1_WHN1']")
for i in price:
    if i.text is None :
        Price.append("--") 
    else:
        Price.append(i.text)

# Scraping all the product urls
url="https://www.flipkart.com/"
url1=driver.find_element_by_xpath("//a[@class='_1fQZEK']").get_attribute('href')
for i in url:
    #URL.append(i.text)
    Product_URL.append(url1)

# %%
url4 = 'www.flipkart.com'

# %% [markdown]
# __________________________________

# %% [markdown]
# ### 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
import selenium
import pandas as pd
from selenium import webdriver

from time import sleep
import time
import re
import requests

from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
driver = webdriver.Chrome(r"C:\Users\91977\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url5 = 'https://www.google.com/maps'

# %%
driver.get(url5)
time.sleep(2)

# %%
city = input('Enter City Name : ')                                         
search5 = driver.find_element_by_id("searchboxinput")                       
search5.clear()                                                             
time.sleep(1)
search5.send_keys(city)  

button5 = driver.find_element_by_id("searchbox-searchbutton")               
button5.click()                                                             
time.sleep(2)


try:
    url_str = driver.current_url
    print("URL Extracted: ", url_str)
    latitude_longitude = re.findall(r'@(.*)data',url_str)
    if len(latitude_longitude):
        lat_lng_list = latitude_longitude[0].split(",")
        if len(lat_lng_list)>=2:
            latitude = lat_lng_list[0]
            longitude = lat_lng_list[1]
        print("Latitude = {}, Longitude = {}".format(latitude, longitude))

except Exception as e:
        print("Error: ", str(e))
# Out:
# Enter City Name : ballarpur
# URL Extracted:  https://www.google.com/maps/place/Ballarpur,+Maharashtra/@19.8461178,79.3307839,13z/data=!3m1!4b1!4m5!3m4!1s0x3bd2d2ea9f3225a3:0x9771a920a14a7781!8m2!3d19.8515663!4d79.3498917
# Latitude = 19.8461178, Longitude = 79.3307839

# %% [markdown]
# _____________________________________

# %% [markdown]
# ### 6. Write a program to scrap details of all the funding deals for second quarter (i.e. July 20 – September 20) from trak.in.

# %%
import selenium
import pandas as pd
from selenium import webdriver

from time import sleep
import time
import re
import requests

from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
driver = webdriver.Chrome(r"C:\Users\91977\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url6 = 'https://trak.in/'

# %%
driver.get(url6)
time.sleep(2)

# %%
srch_btn6 = driver.find_element_by_xpath('//li[@id="menu-item-51510"]/a').get_attribute('href')
driver.get(srch_btn6)

# %%
#creating Empty List:
Funding_Deal = {}
Funding_Deal['Date'] = []
Funding_Deal['Startup Name'] = []
Funding_Deal['Industry/Vertical'] = []
Funding_Deal['Sub-Vertical'] = []
Funding_Deal['City/Location'] = []
Funding_Deal['Investor'] = []
Funding_Deal['Investment Type'] = []
Funding_Deal['Amount(in USD)'] = []

# %%
#extracting data July 2020, AUgust 2020 and September 2020 funding deals

for j in range(48,51):
    driver.find_element_by_xpath('//div[@id="tablepress-{}_wrapper"]/div/label/select/option[4]'.format(j)).click()
    
    date = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[2]'.format(j))
    for i in date:
        Funding_Deal['Date'].append(i.text)

    startup = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[3]'.format(j))
    for i in startup:
        Funding_Deal['Startup Name'].append(i.text)

            
    industry = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[4]'.format(j))
    for i in industry:
        Funding_Deal['Industry/Vertical'].append(i.text)
            
    sv = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[5]'.format(j))
    for i in sv:
        Funding_Deal['Sub-Vertical'].append(i.text)
            
    location = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[6]'.format(j))
    for i in location:
        Funding_Deal['City/Location'].append(i.text)
            
    investor = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[7]'.format(j))
    for i in investor:
        Funding_Deal['Investor'].append(i.text)
            
    investment_t = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[8]'.format(j))
    for i in investment_t:
        Funding_Deal['Investment Type'].append(i.text)

    amount = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[9]'.format(j))
    for i in amount:
        Funding_Deal['Amount(in USD)'].append(i.text)

# %%
Second_Quarter_Funding_Deals_2020 = pd.DataFrame(Funding_Deal)

# %%
Second_Quarter_Funding_Deals_2020
# Out:
#           Date               Startup Name  \
# 0   15/07/2020                   Flipkart
# 1   16/07/2020                    Vedantu
# 2   16/07/2020                       Crio
# 3   14/07/2020                    goDutch
# 4   13/07/2020                   Mystifly
# 5   09/07/2020               JetSynthesys
# 6   10/07/2020                   gigIndia
# 7   15/07/2020                  PumPumPum
# 8   14/07/2020                       FLYX
# 9   13/07/2020  Open Appliances Pvt. Ltd.
# 10  15/08/2020                     Practo
# 11  13/08/2020                    Medlife
# 12  13/08/2020                  HungerBox
# 13  04/08/2020                      Dunzo
# 14  11/08/2020                   Terra.do
# 15  12/08/2020                  Classplus
# 16  14/08/2020                       Niyo
# 17  10/08/2020                  ZestMoney
# 18  07/08/2020                FreshToHome
# 19  13/08/2020                    Eduvanz
# 20  03/08/2020                 CrowdPouch
# 21  04/08/2020                 DrinkPrime
# 22  08/09/2020                     Byju’s
# 23  12/09/2020                  mCaffeine
# 24  09/09/2020                     Qshala
# 25  02/09/2020                      Winzo
# 26  09/09/2020                Hippo Video
# 27  07/09/2020                    Melorra
# 28  07/09/2020                        1mg
# 29  31/08/2020                      mfine
# 30  31/08/2020                       Apna
# 31  03/09/2020                    Railofy
# 32  08/09/2020            Cell Propulsion
#
#                          Industry/Vertical  \
# 0                               E-commerce
# 1                                  EduTech
# 2                                  EduTech
# 3                                  FinTech
# 4                      Airfare Marketplace
# 5                 Gaming and Entertainment
# 6                              Marketplace
# 7                        Automotive Rental
# 8                               OTT Player
# 9                   Information Technology
# 10                              HealthTech
# 11                              E-commerce
# 12                                FoodTech
# 13                   Hyper-local Logistics
# 14                                 EduTech
# 15                                 EduTech
# 16                                 FinTech
# 17                                 FinTech
# 18                              E-commerce
# 19                                 FinTech
# 20                                 FinTech
# 21                      Water Purification
# 22                                 EduTech
# 23                           Personal Care
# 24                                 EduTech
# 25                           Online Gaming
# 26  Video Customer Experience(CX) Platform
# 27                              E-commerce
# 28                              E-commerce
# 29                              HealthTech
# 30                         Human Resources
# 31                          Transportation
# 32                              Automobile
#
#                                          Sub-Vertical  \
# 0                                          E-commerce
# 1                                     Online Tutoring
# 2                    Learning Platform for Developers
# 3                                      Group Payments
# 4   Ticketing, Airline Retailing, and Post-Ticketi...
# 5                            Gaming and Entertainment
# 6                           Crowd Sourcing, Freelance
# 7                           Used Car-leasing platform
# 8                            Streaming Social Network
# 9               Internet-of-Things Security Solutions
# 10                           Health care and Wellness
# 11                                    Online Pharmacy
# 12                       Online Food Delivery Service
# 13                           Online Delivery Services
# 14                  Online Climate School, E-learning
# 15                        E-learning, Online Tutoring
# 16                                 Financial Services
# 17                                 Financial Services
# 18                                      Food Delivery
# 19                                 Financial Services
# 20                                 Financial Services
# 21                                 Water Purification
# 22                                    Online Tutoring
# 23                                Skincare & Haircare
# 24                 Online Curiosity Platform for Kids
# 25                                      Online Gaming
# 26             Video Customer Experience(CX) Platform
# 27                               Online Jewelry Store
# 28                                    Online Pharmacy
# 29                      On-Demand Healthcare Services
# 30                               Recruitment Platform
# 31                       WL & RAC protection platform
# 32                        Electric Mobility Solutions
#
#                                  City/Location  \
# 0                                    Bangalore
# 1                                    Bangalore
# 2                                    Bangalore
# 3                                       Mumbai
# 4                      Singapore and Bangalore
# 5                                         Pune
# 6                                         Pune
# 7                                      Gurgaon
# 8                           New York and Delhi
# 9                                    Bangalore
# 10                                   Bangalore
# 11                                   Bangalore
# 12                                   Bangalore
# 13                                   Bangalore
# 14                       Stanford, California,
# 15                                       Noida
# 16                                   Bangalore
# 17                                   Bangalore
# 18                                   Bangalore
# 19                                      Mumbai
# 20                                   Bangalore
# 21                                   Bangalore
# 22                                   Bangalore
# 23                                      Mumbai
# 24                                   Bangalore
# 25                                   New Delhi
# 26  Newark, Delaware, United States of Amercia
# 27                                   Bangalore
# 28                                     Gurgaon
# 29                                   Bangalore
# 30                                   Bangalore
# 31                                      Mumbai
# 32                                   Bangalore
#
#                                              Investor         Investment Type  \
# 0                                         Walmart Inc                     M&A
# 1                                   Coatue Management                Series D
# 2                                         021 Capital            pre-Series A
# 3   Matrix India,Y Combinator, Global Founders Cap...                    Seed
# 4                                    Recruit Co. Ltd.            pre-Series B
# 5            Adar Poonawalla and Kris Gopalakrishnan.  Venture-Series Unknown
# 6        Incubate Fund India and Beyond Next Ventures            pre-Series A
# 7                            Early Adapters Syndicate                    Seed
# 8               Raj Mishra, founder of AIT Global Inc                pre-Seed
# 9                              Unicorn India Ventures  Venture-Series Unknown
# 10                                        A1A Company                Series F
# 11         Prasid Uno Family Trust and SC Credit Fund
# 12  One97, Sabre Partners Trust, Pratithi Investme...               Series D1
# 13                                   Existing Backers             In Progress
# 14  Stanford Angels and Entrepreneurs (India), BEE...                    Seed
# 15                                        Falcon Edge             In Progress
# 16                                Niyo Solutions Inc.
# 17                            Primrose Hills Ventures
# 18                                     Ascent Capital                 Venture
# 19                              Sequoia India, Unitus                Series A
# 20                         Elina Investments Pvt. Ltd                   Angel
# 21                        Sequoia Surge, ON Mauritius            Pre-Series A
# 22  Silver Lake, Tiger Global, General Atlantic an...          Private Equity
# 23  Amicus Capital Private Equity I LLP, Amicus Ca...                Series B
# 24                                 Rainmatter Capital                   Angel
# 25  Kalaari Capital Partners, IndigoEdge Managemen...                Series B
# 26  Alpha Wave Incubation, Exfinity Venture Partne...                Series A
# 27                         Shadow Holdings, Lightbox.          Debt Financing
# 28         Gaja Capital, Tata Capital, Partners Group             In Progress
# 29                                   Caretech Pte Inc                Series B
# 30         Lightspeed India and Sequoia Capital India                Series A
# 31                                  Chiratae Ventures                    Seed
# 32                         growX Ventures and Micelio            pre-Series A
#
#      Amount(in USD)
# 0     1,200,000,000
# 1       100,000,000
# 2           934,160
# 3         1,700,000
# 4         3,300,000
# 5           400,000
# 6           974,200
# 7           292,800
# 8           200,000
# 9           500,000
# 10       32,000,000
# 11       23,000,000
# 12        1,560,000
# 13       30,000,000
# 14        1,400,000
# 15  upto 15,000,000
# 16        6,000,000
# 17       10,670,000
# 18       16,200,000
# 19        5,000,000
# 20               NA
# 21        2,880,000
# 22      500,000,000
# 23        3,000,000
# 24          370,000
# 25       15,500,000
# 26        4,500,000
# 27   upto 8,900,000
# 28      100,000,000
# 29        5,400,000
# 30        8,000,000
# 31          950,000
# 32               NA

# %% [markdown]
# __________________________________________________

# %% [markdown]
# ### 7. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
import selenium
import pandas as pd
from selenium import webdriver

from time import sleep
import time
import re
import requests

from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
driver = webdriver.Chrome(r"C:\Users\91977\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url7 = 'https://www.digit.in/'

# %%
driver.get(url7)
time.sleep(2)

# %%
#clicking on top 10 tab
top10=driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[4]/ul/li[4]/a")
top10.click()

time.sleep(2)
#clicking on laptops option
laptop=driver.find_element_by_xpath("/html/body/div[3]/div/div/div[2]/div[5]/div[1]/div/button[2]")
laptop.click()

time.sleep(2)
#best gaming laptops link
best_gaming=driver.find_element_by_xpath("//div[@id='laptops']//div[3]//a")
driver.get(best_gaming.get_attribute('href'))

# %%
#Creating Empty List
Gaming_Laptops = {}
Gaming_Laptops['Laptop_name'] = []
Gaming_Laptops['OS'] = []
Gaming_Laptops['display'] = []
Gaming_Laptops['processor'] = []
Gaming_Laptops['HDD'] = []
Gaming_Laptops['RAM'] = []
Gaming_Laptops['weight'] = []
Gaming_Laptops['dimension'] = []
Gaming_Laptops['GPU'] = []
Gaming_Laptops['price'] = []

time.sleep(1)
#scraping names
names=driver.find_elements_by_xpath("//div[@class='right-container']/div/a/h3")
for i in names:
    Gaming_Laptops['Laptop_name'].append(i.text)

time.sleep(1)
#scraping operating system
os=driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[1]/div/div")
for i in os:
    Gaming_Laptops['OS'].append(i.text)

time.sleep(1)
#scraping display
displays=driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[2]/div/div")
for i in displays:
    Gaming_Laptops['display'].append(i.text)

time.sleep(1)
#scraping processor
processors=driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[3]/div/div")
for i in processors:
    Gaming_Laptops['processor'].append(i.text)

time.sleep(1)
# scraping memory
memories=driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[6]/td[3]")# extrat HDD and RAM form xpath
for i in memories:
    Gaming_Laptops['HDD'].append(i.text.split("/")[0])
    Gaming_Laptops['RAM'].append(i.text.split("/")[1])

time.sleep(1)
# scraping weight
weights=driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[7]/td[3]")# extrat weight form xpath
for i in weights:
    Gaming_Laptops['weight'].append(i.text)

time.sleep(1)
# scraping dimension
dimension=[]
dimensions=driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[8]/td[3]") 
for i in dimensions:
    Gaming_Laptops['dimension'].append(i.text)

time.sleep(1)
# scraping graphical processor
GPUs=driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[9]/td[3]") 
for i in GPUs:
    Gaming_Laptops['GPU'].append(i.text)

time.sleep(1)

#scraping price
price=driver.find_elements_by_xpath("//table[@id='summtable']//tr//td[3]")
for i in price:
    Gaming_Laptops['price'].append(i.text)

# %%
#Make data frame
Gaming_Laptops=pd.DataFrame(Gaming_Laptops)
Gaming_Laptops
# Out:
#                 Laptop_name               OS              display  \
# 0     ALIENWARE AREA 51M R2  WINDOWS 10 HOME  17.3" (1920 X 1080)
# 1          ALIENWARE M15 R3  WINDOWS 10 HOME  15.6" (3840 X 2160)
# 2    ASUS ROG STRIX SCAR 15  WINDOWS 10 HOME  15.6" (1920 X 1080)
# 3     ASUS ROG ZEPHYRUS G14  WINDOWS 10 HOME    14" (1920 X 1080)
# 4          LENOVO LEGION 5I   WINDOWS 10 PRO  15.6" (1920 X 1080)
# 5  ASUS ROG ZEPHYRUS DUO 15       WINDOWS 10  15.6" (3840 X 1100)
# 6      ACER ASPIRE 7 GAMING  WINDOWS 10 HOME  15.6" (1920 X 1080)
#
#                                            processor         HDD  \
# 0   10TH GENERATION INTEL® CORE™ I7-10700 | 2.90 GHZ    1 TB SSD
# 1       10TH GENERATION INTEL® CORE™ I9-10980HK | NA    1 TB SSD
# 2                      AMD RYZEN™ 9 5900HX | 3.3 GHZ    1 TB SSD
# 3               AMD 3RD GENERATION RYZEN 9 | 3.3 GHZ    1 TB SSD
# 4  10TH GENERATION INTEL® CORE™ I5-10300H | 2.50 GHZ    1 TB SSD
# 5                 INTEL CORE I7 10TH GEN 10875H | NA  512 GB SSD
# 6                  AMD RYZEN™ 5-5500U HEXA-CORE | NA  512 GB SSD
#
#             RAM weight                dimension  \
# 0  16 GBGB DDR4    4.1   27.65 x 402.6 x 319.14
# 1  16 GBGB DDR4     NA                       NA
# 2  16 GBGB DDR4   2.30       35.4 x 25.9 x 2.26
# 3  16 GBGB DDR4   1.65        32.5 x 22.1 x 1.8
# 4  16 GBGB DDR4    2.3  363.06 x 259.61 x 23.57
# 5   4 GBGB DDR4    2.4  268.30 x 360.00 x 20.90
# 6   8 GBGB DDR4   2.15       2.29 x 36.3 x 25.4
#
#                              GPU    price
# 0        Intel® UHD Graphics 630      N/A
# 1                             NA  ₹341990
# 2      NVIDIA® GeForce RTX™ 3070      N/A
# 3        NVIDIA GeForce RTX 2060  ₹164990
# 4  NVIDIA® GeForce® GTX 1650 4GB   ₹76988
# 5  NVIDIA GeForce RTX 2070 Max-Q  ₹185000
# 6      NVIDIA® GeForce® GTX 1650   ₹79400

# %% [markdown]
# ___________________

# %% [markdown]
# #### 8. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, "Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
driver = webdriver.Chrome(r"C:\Users\91977\Downloads\chromedriver_win32\chromedriver.exe")

# %%
# Opening the forbes.com
time.sleep(2)
url8 = "https://www.forbes.com/?sh=69e6b8c92254"
driver.get(url8)
time.sleep(2)

#clicking the explore button
button9 = driver.find_element_by_xpath("//button[@class='icon--hamburger']")
button9.click()
time.sleep(1)

#select billioners 
billioners = driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]")
billioners.click()
time.sleep(1)

#select world billioners 
world_billioners= driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a")
world_billioners.click()
time.sleep(1)

# %%
rank=[]
for i in driver.find_elements_by_xpath('//div[@ class="rank"]'):
    rank.append(i.text.replace('\n',''))

# %%
len(rank)
# Out:
# 200

# %%
Name=[]
for i in driver.find_elements_by_xpath('//div[@ class="personName"]'):
    Name.append(i.text.replace('\n',''))

# %%
len(Name)
# Out:
# 200

# %%
Net_worth=[]
for i in driver.find_elements_by_xpath('//div[@ class="netWorth"]'):
    Net_worth.append(i.text.replace('\n',''))

# %%
len(Net_worth)
# Out:
# 200

# %%
Country=[]
for i in driver.find_elements_by_xpath('//div[@ class="countryOfCitizenship"]'):
    Country.append(i.text.replace('\n',''))

# %%
len(Country)
# Out:
# 200

# %%
source=[]
for i in driver.find_elements_by_xpath('//div[@ class="source-column"]'):
    source.append(i.text.replace('\n',''))

# %%
len(source)
# Out:
# 200

# %%
Industry=[]
for i in driver.find_elements_by_xpath('//div[@ class="category"]'):
    Industry.append(i.text.replace('\n',''))

# %%
len(Industry)
# Out:
# 200

# %%
Age=[]
for i in driver.find_elements_by_xpath('//div[@ class="age"]'):
    Age.append(i.text.replace('\n',''))

# %%
len(Age)
# Out:
# 200

# %%
for _ in range(13):
    next = driver.find_element_by_xpath('//button[@class="pagination-btn pagination-btn--next "]')
    next.click()
    for i in driver.find_elements_by_xpath('//div[@ class="rank"]'):
        rank.append(i.text.replace('\n',''))
    for i in driver.find_elements_by_xpath('//div[@ class="personName"]'):
        Name.append(i.text.replace('\n',''))
    for i in driver.find_elements_by_xpath('//div[@ class="netWorth"]'):
        Net_worth.append(i.text.replace('\n',''))
    for i in driver.find_elements_by_xpath('//div[@ class="countryOfCitizenship"]'):
        Country.append(i.text.replace('\n',''))
    for i in driver.find_elements_by_xpath('//div[@ class="source-column"]'):
        source.append(i.text.replace('\n',''))
    for i in driver.find_elements_by_xpath('//div[@ class="category"]'):
        Industry.append(i.text.replace('\n',''))
    for i in driver.find_elements_by_xpath('//div[@ class="age"]'):
        Age.append(i.text.replace('\n',''))

# %%
print(len(rank),len(Name),len(Net_worth),len(Country),len(source),len(Industry),len(Age))
# Out:
# 2755 2755 2755 2755 2755 2755 2755

# %%
Billiniore=pd.DataFrame({})

Billiniore['Rank']=rank
Billiniore['Name']=Name
Billiniore['Net_worth']=Net_worth
Billiniore['Industry']=Industry
Billiniore['Source']=source
Billiniore['Citizenship']=Country
Billiniore['Age']=Age

# %%
Billiniore
# Out:
#        Rank                      Name Net_worth          Industry  \
# 0        1.                Jeff Bezos    $177 B        Technology
# 1        2.                 Elon Musk    $151 B        Automotive
# 2        3.  Bernard Arnault & family    $150 B  Fashion & Retail
# 3        4.                Bill Gates    $124 B        Technology
# 4        5.           Mark Zuckerberg     $97 B        Technology
# ...     ...                       ...       ...               ...
# 2750  2674.         Daniel Yong Zhang      $1 B        Technology
# 2751  2674.             Zhang Yuqiang      $1 B     Manufacturing
# 2752  2674.             Zhao Meiguang      $1 B   Metals & Mining
# 2753  2674.            Zhong Naixiong      $1 B       Diversified
# 2754  2674.           Zhou Wei family      $1 B        Technology
#
#              Source    Citizenship Age
# 0            Amazon  United States  57
# 1     Tesla, SpaceX  United States  49
# 2              LVMH         France  72
# 3         Microsoft  United States  65
# 4          Facebook  United States  36
# ...             ...            ...  ..
# 2750     e-commerce          China  49
# 2751     Fiberglass          China  65
# 2752    gold mining          China  58
# 2753   conglomerate          China  58
# 2754       Software          China  54
#
# [2755 rows x 7 columns]

# %% [markdown]
# _______________________________

# %% [markdown]
# #### 9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
import selenium
import pandas as pd
from selenium import webdriver

from time import sleep
import time
import re
import requests

from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
#connecting to web driver
driver = webdriver.Chrome(r"C:\Users\91977\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url9 = "https://www.youtube.com/watch?v=KPk34_zCt-g"
driver.get(url9)
time.sleep(10)

# %%
# 1000 times the page will be scrolled down by 10000 in order to generate more Comments

time.sleep(10)

for _ in range(400):
    driver.execute_script("window.scrollBy(0,420)")
    time.sleep(10)

# %%
Youtube = {}
Youtube['Comments'] = []
Youtube['Comment_upvote'] = []
Youtube['Time'] = []

# %%
time.sleep(10)
for i in driver.find_elements_by_id('content-text'):
    try:
        Youtube['Comments'].append(i.text.replace('\n',''))
    except NoSuchElementException:
        Youtube['Comments'].append('-')

for i in driver.find_elements_by_id('vote-count-middle'):
    try:
        Youtube['Comment_upvote'].append(i.text)
    except NoSuchElementException:
        Youtube['Comment_upvote'].append('-')

for i in driver.find_elements_by_xpath('//yt-formatted-string[@class="published-time-text above-comment style-scope ytd-comment-renderer"]'):
    try:
        Youtube['Time'].append(i.text.replace('(edited)','').replace('ago',''))
    except NoSuchElementException:
        Youtube['Time'].append('-')

# %%
Youtube_Video = pd.DataFrame(Youtube)

# %%
Youtube_Video
# Out:
#                                                Comments Comment_upvote  \
# 0     Thank You All for the 50 Million Views & 350K ...           1.9K
# 1         Arijit singh ke real fans thoko like ✌👍👍☺☺☺☺☺             26
# 2     औकात ना थी किसी की हाथ लगाने की...पर तेरी मोहब...              6
# 3                       Arijit Singh is king of singing             10
# 4     Heartbreak+ lights off+eyes close+ earphones+A...             49
# ...                                                 ...            ...
# 1324                  ARJIT SINGH IS GOOD SINGER I LIKE             26
# 1325                                     Love this song             16
# 1326  jo gaana arijit singh ne gaa diya bss use hit ...             17
# 1327            Who is watching this in February 😂😂🤣🤣👍👍             43
# 1328               Arjith's song+Earphone+long drive=💘💯            103
#
#             Time
# 0       1 year
# 1      7 months
# 2         1 day
# 3         1 day
# 4        4 days
# ...          ...
# 1324     1 year
# 1325   8 months
# 1326     1 year
# 1327  8 months
# 1328   7 months
#
# [1329 rows x 3 columns]

# %% [markdown]
# __________________

# %% [markdown]
# #### 10. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description.

# %%
#connecting to web driver
driver = webdriver.Chrome(r"C:\Users\91977\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url10 = "https://www.hostelworld.com/"
driver.get(url10)
time.sleep(4)

# %%
driver.find_element_by_id('location-text-input-field').click()
time.sleep(2)

driver.find_element_by_xpath('//*[@id="search-input-field"]').send_keys('London')
time.sleep(4)

driver.find_element_by_xpath('//*[@id="predicted-search-results"]/li[2]').click()

driver.find_element_by_id('search-button').click()

# %%
for j in range(len(hotel_url)):
    driver.get(hotel_url[j])
    for i in driver.find_elements_by_xpath('//div[@class="title-2"]'):
        Hostel['Name'].append(i.text.replace('\n',''))
    for i in driver.find_elements_by_xpath('//div[@ class="score orange big"]'):
        Hostel['ratings'].append(i.text.replace('\n',''))
    
    d = driver.find_element_by_element('//div[@class="content collapse-content"]')
    Hostel['Description'].append(d.text)
    
    f = driver.find_element_by_xpath('//div[@class="facilities-container"]')
    Hostel['Facilities'].append(f.text)

# %%
Hostel = {}
Hostel['Name'] = []
Hostel['Distance'] = []
Hostel['ratings'] = []
Hostel['Total_Reviews'] = []
Hostel['Overall_Reviews'] = []
Hostel['Privates'] = []
Hostel['Price'] = []
Hostel['Dorms'] = []
Hostel['Facilities'] = []
Hostel['Description'] = []

# %% [raw]
# dist_city = []
#
# for j in range(0,len(distance_city_centre),2):
#     dist_city.append(distance_city_centre[j])

# %%
driver = webdriver.Chrome(r"C:\Users\91977\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url10 = "https://www.hostelworld.com/"
driver.get(url10)
time.sleep(4)

# %%
driver.find_element_by_id('location-text-input-field').click()
time.sleep(2)

driver.find_element_by_xpath('//*[@id="search-input-field"]').send_keys('London')
time.sleep(4)

driver.find_element_by_xpath('//*[@id="predicted-search-results"]/li[2]').click()

driver.find_element_by_id('search-button').click()

# %%
time.sleep(8)
#try:
    #driver.find_element_by_xpath('//div[@class="pagination-item"]').click()
    #time.sleep(2)
#except:
    #pass

urls = []
try:
    for _ in range(0,3):
        links = driver.find_elements_by_xpath('//div[@class="title-row"]//a')

        for url in links:
            urls.append(url.get_attribute('href'))
        driver.find_element_by_xpath('//div[@class="pagination-item pagination-next"]').click()
        time.sleep(5)
    len(urls)

except:
    pass

# %%
links = []
for i in range(0,len(urls),2):
    links.append(urls[i])

# %%
hostel_name = []
ratings = []
total_reviews = []
overall_reviews = []
facilities = []
description = []

for i in links:
    driver.get(i)
    time.sleep(3)
    name = driver.find_element_by_xpath('//div[@class="headline-container"]//div//h1//div')
    rate = driver.find_element_by_xpath('//div[@class="rating rating-summary-container big clickable"]//div')
    revs = driver.find_element_by_xpath('//div[@class="reviews"]')
    over = driver.find_element_by_xpath('//div[@class="rating-factors rating-factors big"]')
    #faci = driver.find_element_by_xpath('/html/body/div[1]/div/div/div[1]/section/div[11]/div/ul/li[1]/ul')
    faci = driver.find_element_by_xpath('//div[@class="facilities-container"]')
    #desc = driver.find_element_by_xpath('//*[@id="__layout"]/div/div[1]/section/div[6]/div/div[2]/div[2]/div/div[2]')
    
    try:
        hostel_name.append(name.text)
    except NoSuchElementException:
        hostel_name.append('-')
    try:    
        ratings.append(rate.text)
    except NoSuchElementException:
        ratings.append('-')
    try:
        total_reviews.append(revs.text)
    except NoSuchElementException:
        total_reviews.append('-')
    try:
        overall_reviews.append(over.text)
    except NoSuchElementException:
        overall_reviews.append('-')
    try:
        facilities.append(faci.text)
    except NoSuchElementException:
        facilities.append('-')
    try:
        desc = driver.find_element_by_xpath('//div[@class="content collapse-content"]')
        description.append(desc.text)
    except NoSuchElementException:
        description.append('-')
   
        
    time.sleep(3)

# %%
driver = webdriver.Chrome(r"C:\Users\91977\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url10 = "https://www.hostelworld.com/"
driver.get(url10)
time.sleep(4)

# %%
driver.find_element_by_id('location-text-input-field').click()
time.sleep(2)

driver.find_element_by_xpath('//*[@id="search-input-field"]').send_keys('London')
time.sleep(4)

driver.find_element_by_xpath('//*[@id="predicted-search-results"]/li[2]').click()

driver.find_element_by_id('search-button').click()

# %%
privates_from_price = []
dorms_from_price = []
distance_city_centre = [] 

for _ in range(0,3):
    try:
        dist = driver.find_elements_by_xpath('//a[@class="show-on-map"]//span[1]')
        priv = driver.find_elements_by_xpath('//div[@class="prices-col"]//a//div[1]//p')
        dorm = driver.find_elements_by_xpath('//div[@class="prices-col"]//a[1]//div[2]')

        for i in dist:
            try:
                distance_city_centre.append(i.text)
            except NoSuchElementException:
                distance_city_centre.append('-')
        
        for j in priv:
            privates_from_price.append(j.text.replace('Privates From\n',''))
    
        for k in dorm:
            dorms_from_price.append(k.text.replace('Dorms From\n',''))

        
        driver.find_element_by_xpath('//div[@class="pagination-item pagination-next"]').click()
        time.sleep(4)
    except NoSuchElementException:
        distance_city_centre.append('-')
        privates_from_price.append('-')
        dorms_from_price.append('-')

# %%
distance_city_centre = distance_city_centre[:87]
privates_from_price = privates_from_price[:87]        
dorms_from_price = dorms_from_price[:87]

# %%
#creating dataframe
Hostel_Details = pd.DataFrame({'Hostel Name':hostel_name,
                'Distance from city centre':distance_city_centre,
                'Overall Review':overall_reviews,
                'Total Reviews':total_reviews,
                'Facilities':facilities,
                'Privates From Price':privates_from_price,
                'Dorms From Price':dorms_from_price,
                'Ratings':ratings,
                'Property Description':description
                  })

# %%
Hostel_Details[:20]
# Out:
#                              Hostel Name  \
# 0                               SoHostel
# 1             PubLove @ The Rose & Crown
# 2               St Christopher's Village
# 3                 London Waterloo Hostel
# 4    PubLove @ The White Ferry, Victoria
# 5        Wombat's The City Hostel London
# 6                         Phoenix Hostel
# 7                  The Dictionary Hostel
# 8   PubLove @ The Steam Engine, Waterloo
# 9                     Strand Continental
# 10                      Generator London
# 11                       Astor Hyde Park
# 12    St Christopher's Oasis-Female Only
# 13                        Astor Victoria
# 14           Smart Russell Square Hostel
# 15                    No.8 Seven Sisters
# 16                  New Cross Inn Hostel
# 17        PubLove @ The Crown, Battersea
# 18    PubLove @ The Exmouth Arms, Euston
# 19                    London Backpackers
#
#                      Distance from city centre  \
# 0                Hostel - 2km from city centre
# 1              Hostel - 1.6km from city centre
# 2              Hostel - 1.8km from city centre
# 3              Hostel - 0.7km from city centre
# 4              Hostel - 2.4km from city centre
# 5              Hostel - 3.6km from city centre
# 6              Hostel - 4.2km from city centre
# 7              Hostel - 0.5km from city centre
# 8              Hostel - 1.3km from city centre
# 9                Hostel - 3km from city centre
# 10             Hostel - 4.3km from city centre
# 11             Hostel - 1.8km from city centre
# 12             Hostel - 1.8km from city centre
# 13  Bed and Breakfast - 6.7km from city centre
# 14             Hostel - 2.6km from city centre
# 15               Hostel - 9km from city centre
# 16             Hostel - 6.1km from city centre
# 17             Hostel - 4.7km from city centre
# 18             Hostel - 3.4km from city centre
# 19            Hostel - 11.9km from city centre
#
#                                        Overall Review        Total Reviews  \
# 0   Perfect Location\nSuperb Staff\nFantastic Clea...   3952 Total Reviews
# 1   Wonderful Location\nMarvellous Staff\nExcellen...     99 Total Reviews
# 2   Perfect Location\nSuperb Staff\nFantastic Clea...  10820 Total Reviews
# 3   Perfect Location\nSuperb Staff\nExcellent Clea...   2400 Total Reviews
# 4   Perfect Location\nSuperb Staff\nFantastic Clea...    130 Total Reviews
# 5   Perfect Location\nSuperb Staff\nFantastic Clea...  13130 Total Reviews
# 6   Perfect Location\nSuperb Staff\nExcellent Clea...   3405 Total Reviews
# 7                                                          0 Total Reviews
# 8   Perfect Location\nSuperb Staff\nFantastic Clea...    186 Total Reviews
# 9   Perfect Location\nSuperb Staff\nFantastic Clea...    770 Total Reviews
# 10  Perfect Location\nMarvellous Staff\nExcellent ...   6733 Total Reviews
# 11  Perfect Location\nSuperb Staff\nFantastic Clea...  11321 Total Reviews
# 12   Perfect Location\nSuperb Staff\nGood Cleanliness    593 Total Reviews
# 13  Perfect Location\nSuperb Staff\nFantastic Clea...  14703 Total Reviews
# 14  Perfect Location\nBrilliant Staff\nAwesome Cle...   9499 Total Reviews
# 15  Wonderful Location\nSuperb Staff\nAwesome Clea...   3601 Total Reviews
# 16  Wonderful Location\nMarvellous Staff\nAwesome ...    999 Total Reviews
# 17  Wonderful Location\nMarvellous Staff\nGood Cle...    207 Total Reviews
# 18  Perfect Location\nMarvellous Staff\nExcellent ...    975 Total Reviews
# 19  Perfect Location\nSuperb Staff\nFantastic Clea...   4112 Total Reviews
#
#                                            Facilities    Privates From Price  \
# 0   Facilities\nFree\nLinen Included Free City Map...  No Privates Available
# 1   Facilities\nFree\nLinen Included Free City Map...  No Privates Available
# 2   Facilities\nFree\nLinen Included Free City Map...          Privates From
# 3   Facilities\nFree\nFree Breakfast Linen Include...  No Privates Available
# 4   Facilities\nFree\nLinen Included Free City Map...          Privates From
# 5   Facilities\nFree\nLinen Included Free City Map...          Privates From
# 6   Facilities\nFree\nLinen Included Free City Map...          Privates From
# 7   Facilities\nFree\nLinen Included Free City Map...  No Privates Available
# 8   Facilities\nFree\nLinen Included Free City Map...          Privates From
# 9   Facilities\nFree\nFree Breakfast\nGeneral\nCom...          Privates From
# 10  Facilities\nFree\nLinen Included Free City Map...          Privates From
# 11  Facilities\nFree\nLinen Included Free City Map...          Privates From
# 12  Facilities\nFree\nLinen Included Free City Map...          Privates From
# 13  Facilities\nFree\nLinen Included Free City Map...          Privates From
# 14  Facilities\nFree\nLinen Included Free City Map...  No Privates Available
# 15  Facilities\nFree\nLinen Included Free WiFi\nGe...  No Privates Available
# 16  Facilities\nFree\nFree Breakfast Linen Include...          Privates From
# 17  Facilities\nFree\nLinen Included Free City Map...          Privates From
# 18  Facilities\nFree\nLinen Included Free City Map...          Privates From
# 19  Facilities\nFree\nFree Breakfast Linen Include...          Privates From
#
#       Dorms From Price                     Ratings  \
# 0               Rs2050                         8.9
# 1               Rs1538                         7.4
# 2               Rs1510                         8.9
# 3               Rs1276                         8.0
# 4               Rs1538                         8.9
# 5               Rs2047                         9.3
# 6               Rs1476                         8.5
# 7               Rs1538  No Rating\n0 Total Reviews
# 8               Rs1938                         8.9
# 9               Rs1948                         8.3
# 10              Rs1538                         7.6
# 11              Rs1613                         9.1
# 12              Rs1743                         8.6
# 13  No Dorms Available                          10
# 14              Rs1071                         7.3
# 15               Rs661                         7.7
# 16              Rs1183                         7.3
# 17              Rs1538                         6.8
# 18              Rs1538                         7.5
# 19              Rs1015                         8.7
#
#                                  Property Description
# 0   *Hostel Update*\nOur doors will remain open to...
# 1   Food & culture lovers, assemble!\nThe Rose & C...
# 2   COVID 19 Policy Update.\nIn response to Corona...
# 3   COVID-19 Policy Update\n\nIn response to Coron...
# 4   Walk to the river, turn left, and just keep wa...
# 5   Wombat's The City Hostel London is definitely ...
# 6   *Please note we are operating on LIMITED recep...
# 7   A friendly hostel situated in the heart of Sho...
# 8   The heart & soul of London backpacking\nPull u...
# 9   Welcome to one of London's cheapest, friendlie...
# 10  Generator London is a design hotel-hostel loca...
# 11  Located in the most beautiful and charming nei...
# 12  COVID 19 Policy Update.\nIn response to Corona...
# 13  With Victoria Station and Buckingham Palace a ...
# 14  Nestled in the heart of London, walking distan...
# 15  UNFORTUNATELY WE DO NOT HAVE THE FACILITIES TO...
# 16  Welcome to New Cross Inn Hostel!\n\nA Friendly...
# 17  Do London like a local.\nStay just outside the...
# 18  Do Camden by day and curb side beers by night....
# 19  IMPORTANT NOTICE: This hostel is for 18–35-yea...

# %% [markdown]
# ________________________
